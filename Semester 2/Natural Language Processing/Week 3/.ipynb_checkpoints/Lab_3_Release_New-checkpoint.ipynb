# %% [markdown]
# # Lab 3: Embedding Visualisation
# *   **Course**: CM52065 Natural Language Processing
# *   **Author**: Dr. Andrew Barnes
#
# ## Overview
# In this week's lab you will be using common NLP libraries to implement, visualise and then apply word embeddings to a multilingual dataset.
#
# The learning objectives for this lab are as follows:
#
# 1. Apply static embeddings using Word2Vec.
# 2. Apply contextual embeddings.
# 3. Visualise and compare embeddings using PCA.
#
# To achieve these objectives we will be using a corpus of English and Spanish sentences to illustrate multilingual approaches.
#
# ## Packages
#
# To get started we need to install a number of additional NLP packages, notably gensim and allennlp.

# %%
# !pip install gensim
# !pip install gensim transformers torch sentencepiece
# Out:
# Requirement already satisfied: gensim in /opt/anaconda3/envs/hackathon/lib/python3.13/site-packages (4.4.0)
# Requirement already satisfied: numpy>=1.18.5 in /opt/anaconda3/envs/hackathon/lib/python3.13/site-packages (from gensim) (2.5.1)
# Requirement already satisfied: scipy>=1.7.0 in /opt/anaconda3/envs/hackathon/lib/python3.13/site-packages (from gensim) (1.18.0)
# Requirement already satisfied: smart_open>=1.8.1 in /opt/anaconda3/envs/hackathon/lib/python3.13/site-packages (from gensim) (8.0.0)
# Requirement already satisfied: wrapt in /opt/anaconda3/envs/hackathon/lib/python3.13/site-packages (from smart_open>=1.8.1->gensim) (2.2.2)
# Requirement already satisfied: gensim in /opt/anaconda3/envs/hackathon/lib/python3.13/site-packages (4.4.0)
# Requirement already satisfied: transformers in /opt/anaconda3/envs/hackathon/lib/python3.13/site-packages (5.13.1)
# Requirement already satisfied: torch in /opt/anaconda3/envs/hackathon/lib/python3.13/site-packages (2.13.0)
# Requirement already satisfied: sentencepiece in /opt/anaconda3/envs/hackathon/lib/python3.13/site-packages (0.2.1)
# Requirement already satisfied: numpy>=1.18.5 in /opt/anaconda3/envs/hackathon/lib/python3.13/site-packages (from gensim) (2.5.1)
# Requirement already satisfied: scipy>=1.7.0 in /opt/anaconda3/envs/hackathon/lib/python3.13/site-packages (from gensim) (1.18.0)
# Requirement already satisfied: smart_open>=1.8.1 in /opt/anaconda3/envs/hackathon/lib/python3.13/site-packages (from gensim) (8.0.0)
# Requirement already satisfied: huggingface-hub<2.0,>=1.5.0 in /opt/anaconda3/envs/hackathon/lib/python3.13/site-packages (from transformers) (1.23.0)
# Requirement already satisfied: packaging>=20.0 in /opt/anaconda3/envs/hackathon/lib/python3.13/site-packages (from transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /opt/anaconda3/envs/hackathon/lib/python3.13/site-packages (from transformers) (6.0.3)
# Requirement already satisfied: regex>=2025.10.22 in /opt/anaconda3/envs/hackathon/lib/python3.13/site-packages (from transformers) (2026.2.28)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /opt/anaconda3/envs/hackathon/lib/python3.13/site-packages (from transformers) (0.22.2)
# Requirement already satisfied: typer in /opt/anaconda3/envs/hackathon/lib/python3.13/site-packages (from transformers) (0.26.8)
# Requirement already satisfied: safetensors>=0.8.0 in /opt/anaconda3/envs/hackathon/lib/python3.13/site-packages (from transformers) (0.8.0)
# Requirement already satisfied: tqdm>=4.60 in /opt/anaconda3/envs/hackathon/lib/python3.13/site-packages (from transformers) (4.68.4)
# Requirement already satisfied: click<9.0.0,>=8.4.2 in /opt/anaconda3/envs/hackathon/lib/python3.13/site-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (8.4.2)
# Requirement already satisfied: filelock>=3.10.0 in /opt/anaconda3/envs/hackathon/lib/python3.13/site-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (3.25.2)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/anaconda3/envs/hackathon/lib/python3.13/site-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (2026.6.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.5.1 in /opt/anaconda3/envs/hackathon/lib/python3.13/site-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (1.5.1)
# Requirement already satisfied: httpx<1,>=0.23.0 in /opt/anaconda3/envs/hackathon/lib/python3.13/site-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (0.28.1)
# Requirement already satisfied: typing-extensions>=4.1.0 in /opt/anaconda3/envs/hackathon/lib/python3.13/site-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (4.15.0)
# Requirement already satisfied: anyio in /opt/anaconda3/envs/hackathon/lib/python3.13/site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (4.12.1)
# Requirement already satisfied: certifi in /opt/anaconda3/envs/hackathon/lib/python3.13/site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in /opt/anaconda3/envs/hackathon/lib/python3.13/site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (1.0.9)
# Requirement already satisfied: idna in /opt/anaconda3/envs/hackathon/lib/python3.13/site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (3.11)
# Requirement already satisfied: h11>=0.16 in /opt/anaconda3/envs/hackathon/lib/python3.13/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (0.16.0)
# Requirement already satisfied: setuptools>=77.0.3 in /opt/anaconda3/envs/hackathon/lib/python3.13/site-packages (from torch) (80.10.2)
# Requirement already satisfied: sympy>=1.13.3 in /opt/anaconda3/envs/hackathon/lib/python3.13/site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /opt/anaconda3/envs/hackathon/lib/python3.13/site-packages (from torch) (3.6.1)
# Requirement already satisfied: jinja2 in /opt/anaconda3/envs/hackathon/lib/python3.13/site-packages (from torch) (3.1.6)
# Requirement already satisfied: wrapt in /opt/anaconda3/envs/hackathon/lib/python3.13/site-packages (from smart_open>=1.8.1->gensim) (2.2.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/anaconda3/envs/hackathon/lib/python3.13/site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/anaconda3/envs/hackathon/lib/python3.13/site-packages (from jinja2->torch) (3.0.2)
# Requirement already satisfied: shellingham>=1.3.0 in /opt/anaconda3/envs/hackathon/lib/python3.13/site-packages (from typer->transformers) (1.5.4)
# Requirement already satisfied: rich>=13.8.0 in /opt/anaconda3/envs/hackathon/lib/python3.13/site-packages (from typer->transformers) (15.0.0)
# Requirement already satisfied: annotated-doc>=0.0.2 in /opt/anaconda3/envs/hackathon/lib/python3.13/site-packages (from typer->transformers) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/anaconda3/envs/hackathon/lib/python3.13/site-packages (from rich>=13.8.0->typer->transformers) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/anaconda3/envs/hackathon/lib/python3.13/site-packages (from rich>=13.8.0->typer->transformers) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /opt/anaconda3/envs/hackathon/lib/python3.13/site-packages (from markdown-it-py>=2.2.0->rich>=13.8.0->typer->transformers) (0.1.2)

# %%
import sys

# !{sys.executable} -m pip install spacy
# Out:
# Requirement already satisfied: spacy in /opt/anaconda3/envs/hackathon/lib/python3.13/site-packages (3.8.14)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /opt/anaconda3/envs/hackathon/lib/python3.13/site-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /opt/anaconda3/envs/hackathon/lib/python3.13/site-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /opt/anaconda3/envs/hackathon/lib/python3.13/site-packages (from spacy) (1.0.15)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /opt/anaconda3/envs/hackathon/lib/python3.13/site-packages (from spacy) (2.0.13)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /opt/anaconda3/envs/hackathon/lib/python3.13/site-packages (from spacy) (3.0.13)
# Requirement already satisfied: thinc<8.4.0,>=8.3.12 in /opt/anaconda3/envs/hackathon/lib/python3.13/site-packages (from spacy) (8.3.13)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /opt/anaconda3/envs/hackathon/lib/python3.13/site-packages (from spacy) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.5.3 in /opt/anaconda3/envs/hackathon/lib/python3.13/site-packages (from spacy) (2.5.3)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /opt/anaconda3/envs/hackathon/lib/python3.13/site-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<2.0.0,>=1.0.0 in /opt/anaconda3/envs/hackathon/lib/python3.13/site-packages (from spacy) (1.0.0)
# Requirement already satisfied: confection<2.0.0,>=1.3.2 in /opt/anaconda3/envs/hackathon/lib/python3.13/site-packages (from spacy) (1.3.3)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /opt/anaconda3/envs/hackathon/lib/python3.13/site-packages (from spacy) (0.26.8)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /opt/anaconda3/envs/hackathon/lib/python3.13/site-packages (from spacy) (4.68.4)
# Requirement already satisfied: numpy>=1.19.0 in /opt/anaconda3/envs/hackathon/lib/python3.13/site-packages (from spacy) (2.5.1)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /opt/anaconda3/envs/hackathon/lib/python3.13/site-packages (from spacy) (2.32.5)
# Requirement already satisfied: pydantic<3.0.0,>=2.0.0 in /opt/anaconda3/envs/hackathon/lib/python3.13/site-packages (from spacy) (2.12.5)
# Requirement already satisfied: jinja2 in /opt/anaconda3/envs/hackathon/lib/python3.13/site-packages (from spacy) (3.1.6)
# Requirement already satisfied: setuptools in /opt/anaconda3/envs/hackathon/lib/python3.13/site-packages (from spacy) (80.10.2)
# Requirement already satisfied: packaging>=20.0 in /opt/anaconda3/envs/hackathon/lib/python3.13/site-packages (from spacy) (25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/anaconda3/envs/hackathon/lib/python3.13/site-packages (from pydantic<3.0.0,>=2.0.0->spacy) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /opt/anaconda3/envs/hackathon/lib/python3.13/site-packages (from pydantic<3.0.0,>=2.0.0->spacy) (2.41.5)
# Requirement already satisfied: typing-extensions>=4.14.1 in /opt/anaconda3/envs/hackathon/lib/python3.13/site-packages (from pydantic<3.0.0,>=2.0.0->spacy) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in /opt/anaconda3/envs/hackathon/lib/python3.13/site-packages (from pydantic<3.0.0,>=2.0.0->spacy) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/anaconda3/envs/hackathon/lib/python3.13/site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/envs/hackathon/lib/python3.13/site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/envs/hackathon/lib/python3.13/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/envs/hackathon/lib/python3.13/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2026.1.4)
# Requirement already satisfied: blis<1.4.0,>=1.3.0 in /opt/anaconda3/envs/hackathon/lib/python3.13/site-packages (from thinc<8.4.0,>=8.3.12->spacy) (1.3.3)
# Requirement already satisfied: shellingham>=1.3.0 in /opt/anaconda3/envs/hackathon/lib/python3.13/site-packages (from typer<1.0.0,>=0.3.0->spacy) (1.5.4)
# Requirement already satisfied: rich>=13.8.0 in /opt/anaconda3/envs/hackathon/lib/python3.13/site-packages (from typer<1.0.0,>=0.3.0->spacy) (15.0.0)
# Requirement already satisfied: annotated-doc>=0.0.2 in /opt/anaconda3/envs/hackathon/lib/python3.13/site-packages (from typer<1.0.0,>=0.3.0->spacy) (0.0.4)
# Requirement already satisfied: cloudpathlib>=0.7.0 in /opt/anaconda3/envs/hackathon/lib/python3.13/site-packages (from weasel<2.0.0,>=1.0.0->spacy) (0.24.0)
# Requirement already satisfied: smart-open>=5.2.1 in /opt/anaconda3/envs/hackathon/lib/python3.13/site-packages (from weasel<2.0.0,>=1.0.0->spacy) (8.0.0)
# Requirement already satisfied: httpx>=0.24.0 in /opt/anaconda3/envs/hackathon/lib/python3.13/site-packages (from weasel<2.0.0,>=1.0.0->spacy) (0.28.1)
# Requirement already satisfied: anyio in /opt/anaconda3/envs/hackathon/lib/python3.13/site-packages (from httpx>=0.24.0->weasel<2.0.0,>=1.0.0->spacy) (4.12.1)
# Requirement already satisfied: httpcore==1.* in /opt/anaconda3/envs/hackathon/lib/python3.13/site-packages (from httpx>=0.24.0->weasel<2.0.0,>=1.0.0->spacy) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /opt/anaconda3/envs/hackathon/lib/python3.13/site-packages (from httpcore==1.*->httpx>=0.24.0->weasel<2.0.0,>=1.0.0->spacy) (0.16.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/anaconda3/envs/hackathon/lib/python3.13/site-packages (from rich>=13.8.0->typer<1.0.0,>=0.3.0->spacy) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/anaconda3/envs/hackathon/lib/python3.13/site-packages (from rich>=13.8.0->typer<1.0.0,>=0.3.0->spacy) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /opt/anaconda3/envs/hackathon/lib/python3.13/site-packages (from markdown-it-py>=2.2.0->rich>=13.8.0->typer<1.0.0,>=0.3.0->spacy) (0.1.2)
# Requirement already satisfied: wrapt in /opt/anaconda3/envs/hackathon/lib/python3.13/site-packages (from smart-open>=5.2.1->weasel<2.0.0,>=1.0.0->spacy) (2.2.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/anaconda3/envs/hackathon/lib/python3.13/site-packages (from jinja2->spacy) (3.0.2)

# %%
# !{sys.executable} -m spacy download xx_ent_wiki_sm
# Out:
# Collecting xx-ent-wiki-sm==3.8.0
#   Using cached https://github.com/explosion/spacy-models/releases/download/xx_ent_wiki_sm-3.8.0/xx_ent_wiki_sm-3.8.0-py3-none-any.whl (11.1 MB)
# ✔ Download and installation successful
# You can now load the package via spacy.load('xx_ent_wiki_sm')

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/kamalrajanisrani/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
import sys
# !{sys.executable} -m pip install pandas
# Out:
# Requirement already satisfied: pandas in /opt/anaconda3/envs/hackathon/lib/python3.13/site-packages (3.0.3)
# Requirement already satisfied: numpy>=1.26.0 in /opt/anaconda3/envs/hackathon/lib/python3.13/site-packages (from pandas) (2.5.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/envs/hackathon/lib/python3.13/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/envs/hackathon/lib/python3.13/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %% [markdown]
# ## Dataset
#
# The dataset provided for this lab contains English to Spanish sentence pairs.
#
# ### 1.1 Loading the dataset
# Ensure the `eng_esp.tsv` file has been uploaded to Colab or is available locally then run the code below.
#
# > NOTE: I have limited the dataset to 2500 sentences for illustration purpposes, if you're confident with this lab feel free to expand this to 10,000 or more!

# %%
import pandas as pd

# %%
dataset = pd.read_csv('eng_esp.tsv', sep='\t')[:2500]

# %%
dataset
# Out:
#        1276                              Let's try something.     2481  \
# 0      1277                            I have to go to sleep.     2482
# 1      1280  Today is June 18th and it is Muiriel's birthday!     2485
# 2      1280  Today is June 18th and it is Muiriel's birthday!  1130137
# 3      1282                                Muiriel is 20 now.     2487
# 4      1282                                Muiriel is 20 now.  1130133
# ...     ...                                               ...      ...
# 2495  17456                              I'll lend it to you.   678821
# 2496  17460                      We'll give you your revenge.  1478574
# 2497  17462                         I'll make you a new suit.  2087270
# 2498  17463                  Let me give you a bit of advice.   765251
# 2499  17464                   I will never forget seeing you.   496100
#
#                                       ¡Intentemos algo!
# 0                              Tengo que irme a dormir.
# 1     ¡Hoy es 18 de junio y es el cumpleaños de Muir...
# 2     ¡Hoy es el 18 de junio y es el cumpleaños de M...
# 3                         Ahora, Muiriel tiene 20 años.
# 4                          Muiriel tiene 20 años ahora.
# ...                                                 ...
# 2495                                   Yo te lo presto.
# 2496                        Te otorgaremos tu venganza.
# 2497                   Le confeccionaré un traje nuevo.
# 2498                           Déjame darte un consejo.
# 2499                      Nunca olvidaré haberte visto.
#
# [2500 rows x 4 columns]

# %%
dataset.rename(columns={'1276': 'IdxE', "Let's try something.": 'English', '2481': 'IdxS', '¡Intentemos algo!': 'Spanish'} ,inplace=True)

# %%
dataset
# Out:
#        IdxE                                           English     IdxS  \
# 0      1277                            I have to go to sleep.     2482
# 1      1280  Today is June 18th and it is Muiriel's birthday!     2485
# 2      1280  Today is June 18th and it is Muiriel's birthday!  1130137
# 3      1282                                Muiriel is 20 now.     2487
# 4      1282                                Muiriel is 20 now.  1130133
# ...     ...                                               ...      ...
# 2495  17456                              I'll lend it to you.   678821
# 2496  17460                      We'll give you your revenge.  1478574
# 2497  17462                         I'll make you a new suit.  2087270
# 2498  17463                  Let me give you a bit of advice.   765251
# 2499  17464                   I will never forget seeing you.   496100
#
#                                                 Spanish
# 0                              Tengo que irme a dormir.
# 1     ¡Hoy es 18 de junio y es el cumpleaños de Muir...
# 2     ¡Hoy es el 18 de junio y es el cumpleaños de M...
# 3                         Ahora, Muiriel tiene 20 años.
# 4                          Muiriel tiene 20 años ahora.
# ...                                                 ...
# 2495                                   Yo te lo presto.
# 2496                        Te otorgaremos tu venganza.
# 2497                   Le confeccionaré un traje nuevo.
# 2498                           Déjame darte un consejo.
# 2499                      Nunca olvidaré haberte visto.
#
# [2500 rows x 4 columns]

# %%
print("=== Sentence 1")
print(f"English: \"{dataset.iloc[0, 1]}\"")
print(f"Spanish: \"{dataset.iloc[0, 3]}\"")

print("\n=== Sentence 5")
print(f"English: \"{dataset.iloc[5, 1]}\"")
print(f"Spanish: \"{dataset.iloc[5, 3]}\"")
# Out:
# === Sentence 1
# English: "I have to go to sleep."
# Spanish: "Tengo que irme a dormir."
#
# === Sentence 5
# English: "The password is "Muiriel"."
# Spanish: "La contraseña es "Muiriel"."

# %% [markdown]
# ## Part 1: Preprocessing
#
# Before we can embed the documents we must first preprocess them; however, this time we need to preprocess in multiple languages and so `spacy.load('en')` will not be appropriate as it was trained using English corpora. Instead, we must make use of a multilingual model which included Spanish in its training.
#
# Below, I have provided code to load spacy using a multilingual model alongisde a method which tokenises a given sentence.

# %%
from string import punctuation
from nltk.corpus import stopwords
from tqdm.notebook import tqdm
import spacy

# Load small multilingual model
nlp = spacy.load("xx_ent_wiki_sm")

# Load stop words for English and Spanish
sw_eng, sw_esp = list(stopwords.words('english')), list(stopwords.words('spanish'))

def tokenise(sentence, lan='en'):
  sentence = sentence.translate(str.maketrans('', '', punctuation))             # Punctuation removal
  processed_doc = nlp(sentence)                                                 # Conversion
  tokens = [token.text.lower() for token in processed_doc]                      # Tokenise
  return [w for w in tokens if not w in (sw_eng if (lan == 'en') else sw_esp)]  # Stopword removal

# %%
def get_tokenised_documents(corpus):
  tokenised_english = []
  tokenised_spanish = []
  ### BEGIN CODE ###
  #print(corpus)
  for idx, rows in corpus.iterrows():
    if rows['English']:
      tokenised_english.append(tokenise(rows['English'], 'en'))
    if rows['Spanish']:
      tokenised_spanish.append(tokenise(rows['Spanish'], 'es'))


  ### END CODE ###
  return tokenised_english, tokenised_spanish

# %%
token_english, token_spanish = get_tokenised_documents(dataset)

# %%
if (token_english[50] == ['world', 'werent', 'shape', 'could', 'trust', 'anyone']) and (token_spanish[50] == ['si', 'mundo', 'podría', 'confiar', 'cualquiera']):
  print("Passed!")
else:
  print("Tests failed!")
  print(f"=== English expected: ['world', 'werent', 'shape', 'could', 'trust', 'anyone'], English received: {token_english[50]}")
  print(f"=== Spanish expected: ['si', 'mundo', 'podría', 'confiar', 'cualquiera'], Welsh received: {token_spanish[50]}")
# Out:
# Passed!

# %% [markdown]
# ## Part 2: Static Embeddings
#
# In this second part we will produce static word embeddings and visualise the outcomes.

# %% [markdown]
# ### Word2Vec
#
# The `gensim` package provides a nice class `Word2Vec(...)` which allows us to generate and train both types of Word2Vec model. For example, to produce a Word2Vec model approach we can do the following:
# ```
# model = Word2Vec(
#   sentences=documents,  # The corpus we are using to train the model.
#   vector_size=100,      # Number of hidden nodes.
#   window=3,             # Size of the context window.
#   min_count=0,          # Allows us to apply frequency pruning.
#   sg=0                  # An indicator whether to use CBOW or SkipGram.
# )
# ```
#
# Populate the method below to generate a CBOW Word2Vec model which uses a window size of 1, 100 hidden nodes, and a min_count of 0. If needed you can refer to the documentation [here](https://radimrehurek.com/gensim/models/word2vec.html).

# %%
from gensim.models import Word2Vec

def train_w2v(corpus):
  model = None              # Store your Word2Vec model here
  ### BEGIN CODE
  model = Word2Vec(sentences=corpus, vector_size=100, window=1, min_count=0, sg=0)
  ### END CODE
  return model

# %%
def generate_embeddings(model, corpus):
  """ This method generates embeddings using the given Word2Vec model and corpus """
  embeddings = []
  for sentence in corpus:
    embedding = []
    for word in sentence:
      embedding.append(model.wv[word])
    embeddings.append(embedding)
  return embeddings

### BEGIN CODE

eng_model = train_w2v(token_english)
esp_model = train_w2v(token_spanish)


esp_embeddings = generate_embeddings(esp_model, token_spanish)
eng_embeddings = generate_embeddings(eng_model, token_english)
### END CODE

# %%
if len(token_english[200]) == len(eng_embeddings[200]):
  print("Passed!")
else:
  print(f"Failed! Expected {len(token_english[200])} embeddings, received {len(eng_embeddings[200])}.")
# Out:
# Passed!

# %% [markdown]
# ### Word Similarity
# Awesome work! We have now embedded our English and Spanish corpora and now we will explore these embeddings further.
#
# To start, let's use some built-in functions of the Word2Vec models we trained, specifically we will use the following functions:
# + Check the similarity between two words. `model.wv.similarity(x, y)`
# + Retrieve the `n` most similar words to a given word. `model.wv.most_similar(x, topn=z)`
# + Compute language arithmetic based on learnt vocabulary. `model.wv.most_similar(positive=[x, y], negative=[z], topn=z)`
#
# To aid in using these I have provided the vocabularies for both models below along with a quick function to check if a word exists in each. You are welcome to try tokens not in the vocabulary but you might not get the result you expect...

# %%
word_to_check = "model"
if (word_to_check in eng_model.wv.key_to_index):
  print("Word exists!")
else:
  print("Word does not exist!")

print("English Model Vocabulary:")
print({x for y in token_english for x in y})

print("\n")

word_to_check = "compañía"
if (word_to_check in esp_model.wv.key_to_index):
  print("Word exists!")
else:
  print("Word does not exist!")

print("Spanish Model Vocabulary:")
print({x for y in token_spanish for x in y})
# Out:
# Word exists!
# English Model Vocabulary:
# {'messages', 'brings', 'laughingstock', 'objects', 'nuts', 'witnesses', 'drugs', 'bicycle', 'subsaharan', 'crap', 'arrived', 'offer', 'guarantor', 'nails', 'seriously', 'obey', 'least', 'exams', 'philosophy', 'humans', 'bathroom', 'articulate', 'theoretically', 'helps', 'allowed', 'racket', 'afternoon', 'experience', 'famous', 'kidding', 'days', 'clinton', 'arresting', 'shining', 'mt', 'belong', 'machine', 'occupied', 'leads', 'flaws', 'lasagna', 'harming', 'believed', 'youve', 'criticize', 'creating', 'stay', 'spoke', 'size', 'worth', 'workers', 'government', 'loud', 'win', 'bath', 'silly', 'acted', 'calling', 'pick', 'disappointed', 'card', 'request', 'bullets', 'mammals', '21', 'thank', 'lasted', 'lame', 'silver', 'muiriel', 'items', 'notes', 'profit', 'traveller', 'stupidest', 'ninety', 'opened', 'go', 'laughs', 'poor', 'walk', 'pizza', 'catches', 'begin', 'holmes', 'bored', 'revenge', 'reports', 'tell', 'memory', 'scare', 'verbs', 'intention', 'ah', 'lonely', 'noble', 'suit', 'shower', 'selfishness', '3', 'day', 'library', 'hole', 'use', 'neednt', 'somewhere', 'orders', 'years', 'understanding', 'omit', 'wood', 'short', 'prior', 'though', 'belief', 'unfair', 'impress', 'utterly', 'mere', 'wants', 'helped', 'antisocial', 'interesting', 'compensatory', 'keeps', 'difficult', 'mind', 'proverb', 'within', 'cubic', 'confidence', 'massage', 'hospital', 'formal', 'practical', 'hear', 'live', 'called', 'hows', 'medical', 'vessel', 'account', 'freeze', 'lazy', 'home', 'im', 'maps', 'adversity', 'end', 'cavalieri', 'impossible', 'websites', 'team', 'cursory', 'remain', 'pun', '10', 'makes', 'perhaps', 'nap', 'resign', 'logged', 'allen', 'inspiration', 'apples', 'deed', 'white', 'beauty', 'none', 'crashed', 'luck', 'magnetism', 'starving', 'fail', 'anything', 'ways', 'throne', 'peace', 'expected', 'fearing', 'come', 'searches', 'emphasize', 'address', 'people', 'history', 'beverage', 'requires', 'hat', 'exam', 'fruit', 'advance', 'brush', 'stocking', 'past', 'benefit', 'around', 'species', 'till', 'understands', 'whatever', 'four', 'arguments', 'inquired', 'break', 'japan', 'redundant', 'aspect', 'apartment', 'track', 'intrigue', 'daily', 'anticipating', 'cent', 'real', 'pregnant', 'cupboard', 'brother', 'largest', 'differs', 'hi', 'balanced', 'correct', 'call', 'church', 'par', 'hostel', 'worried', 'prejudiced', 'failed', 'passport', 'art', 'hello', 'life', 'nobody', 'raw', 'tight', 'tyrant', 'highest', 'sung', 'inspired', 'online', 'really', 'slowly', 'masturbate', 'ideas', 'snowman', 'distinguish', 'ago', 'storm', 'entitled', 'aesthetics', 'chemicals', 'viagra', 'pleasing', 'harder', 'wrath', '11th', 'hair', 'orange', 'couple', 'owned', 'think', 'false', 'harry', '1888', 'uh', 'wasnt', 'impression', 'oh', 'tv', 'repudiate', 'wearing', 'consider', 'daughter', 'hockey', 'sunscreen', 'country', '1000', 'translate', 'smart', 'town', 'battle', 'night', 'distance', 'calculus', 'answers', 'convenient', 'david', 'imagine', 'increase', 'story', 'faith', 'everybody', 'maria', 'ashamed', 'deny', 'idea', 'portrait', 'greater', 'dumped', 'deck', 'books', 'lightning', 'evening', 'catch', 'term', 'curious', 'shoes', 'fought', 'vote', 'exert', 'worse', 'cat', 'fruits', 'schooling', 'context', 'grades', 'dare', 'lot', 'nowadays', 'continue', 'rude', 'arrested', 'oclock', 'gain', 'month', 'fast', 'fever', 'typewriter', 'fine', 'lower', 'finns', 'causing', '€', 'transform', 'women', 'needless', 'shortcut', 'wellbeing', 'admits', 'songs', 'umbrella', 'admit', 'evil', 'math', 'everyone', 'close', 'condemned', 'equal', 'rhetorical', 'worst', 'something', 'binary', 'youre', 'madrid', 'outrageous', 'become', 'die', 'colonize', 'sit', 'isnt', 'careful', 'still', 'forget', 'market', 'hot', 'techniques', 'deeds', 'readily', 'mathematical', 'holy', 'tennis', 'scientific', 'never', 'insomniac', 'delayed', 'enjoys', 'insult', 'carefully', 'options', 'copying', 'decision', 'nonlinear', 'waiting', 'italy', 'rain', 'useless', 'trang', 'didnt', 'started', 'knows', ...
#
#
# Word exists!
# Spanish Model Vocabulary:
# {'cosquillas', 'haberle', 'segura', 'claro', 'consideraciones', 'habló', 'pequeño', 'venera', 'episodio', 'cuello', 'haciendo', 'malo', 'coste', 'esperaba', 'arrepiento', 'partes', 'aislarse', 'conocerte', 'nevado', 'cambia', 'distinguir', 'mantenerte', 'dedicas', 'carnet', 'visiones', 'rápido', 'techo', 'belleza', 'preocuparme', 'solar', 'sueños', 'conocer', 'terroristas', 'estudiante', 'valientes', 'acto', 'planeando', 'valdría', 'espía', 'excepto', 'realices', 'échame', 'roble', 'golpear', 'pegarle', 'clinton', 'catarro', 'queremos', 'útiles', 'describiera', 'recientes', 'gastan', 'marcapasos', 'complicada', 'tantos', 'cabeza', 'mirando', 'propósito', 'mercado', 'médico', 'multitud', 'mayores', 'idiomas', 'pegar', 'contraseña', 'sabéis', 'alemán', 'seis', 'terrestres', 'gato', 'elefantes', 'explicarlo', 'jardín', 'escritos', 'pensemos', 'recurrió', 'gustará', 'junio', 'exámenes', 'duda', 'excusa', 'aceptar', '21', 'comprenderías', 'astilla', 'dijiste', 'prestas', 'apartamento', 'disculpas', 'muiriel', 'hecho', 'treinta', 'esperas', 'comenzaremos', 'caramba', 'desperté', 'pantalones', 'programar', 'clínex', 'doy', 'aprobar', 'gasté', 'pizza', 'admitir', 'jurases', 'usted', 'errorcito', 'vietnamita', 'holmes', 'estudies', 'canta', 'reglas', 'licencia', 'lástima', 'diez', 'adulto', 'noble', 'ah', 'poli', 'mesa', 'das', 'miedo', 'cuidado', 'experiencia', 'desear', 'necesites', '3', 'juntarte', 'asistir', 'conseguí', 'falso', 'expresar', 'libertad', 'acortar', 'enfermo', 'domingos', 'mandar', 'formas', 'ayudarla', 'orgullo', 'preparando', 'llamarte', 'cierre', 'inspiración', 'armario', 'diccionario', 'sobrevive', 'acá', 'pule', 'monaguillos', 'comprender', 'impuestos', 'comprado', 'viento', 'cuándo', 'empezar', 'dormir', 'compleja', 'aborrezco', 'hiele', 'rana', 'controlarte', 'avanzada', 'albergue', 'frágil', 'ancha', 'sentí', 'archivo', 'negocio', 'antisocial', 'eternamente', 'reparaciones', 'viene', 'encuesta', 'camiseta', 'vergüenza', 'gastado', 'anillos', 'suficientemente', 'amor', 'año', 'confundido', 'decidí', 'hincapié', 'llegaste', 'café', 'viva', 'escuchar', 'acción', 'contexto', 'explicar', 'hospital', 'formal', 'conducir', 'culpable', 'caro', 'halla', 'planes', 'pintura', 'cosita', 'cambiado', 'consejos', 'piedras', 'tomé', 'abstracto', 'disculpa', 'tales', 'acontecimientos', 'propina', 'intentes', 'lleva', 'idiotas', 'dejaste', 've', 'comen', 'decides', 'complicarse', 'idéntica', 'diccionarios', 'cavalieri', 'nombraron', 'sobornar', 'tranquila', 'bicicletas', 'denunciarlos', 'ganar', 'dificultad', 'buenos', 'despedidas', 'comedia', '10', 'actos', 'cerca', 'sustituta', 'allen', 'tardé', 'venderlos', 'prisa', 'alguien', 'demócrata', 'dietas', 'disculpó', 'último', 'capaz', 'prejuicios', 'consigan', 'ganarse', 'desapareció', 'leyendo', 'asumiendo', 'básica', 'preguntas', 'junta', 'jugo', 'canadá', 'lastimarte', 'plantean', 'respeto', 'detalles', 'aprendemos', 'bastante', 'escuela', 'móvil', 'disculpe', 'coraje', 'aumentado', 'calla', 'éste', 'convencida', 'seleccionados', 'escrita', 'encuentra', 'defectos', 'devuélveme', 'libro', 'amigo', 'intriga', 'movida', 'tráfico', 'tipo', 'creacionismo', 'hablé', 'hagas', 'argumento', 'nunca', 'misterio', 'acostumbrados', 'casi', 'lentes', 'crimen', 'preguntéis', 'preguntad', 'desayunar', 'ropa', 'préstamo', 'perdonaré', 'hacer', 'condiciones', 'artista', 'llevan', 'poder', 'sueñan', 'escalado', 'dilema', 'acostar', 'búsqueda', 'enviaran', 'real', 'cerrada', 'pueda', 'hacerme', 'aburrido', 'irte', 'suscribir', 'usar', 'sonrisa', 'arduamente', 'ciudad', 'saliste', 'comparado', 'ocupados', 'plano', 'semanas', 'par', 'tía', 'niega', 'toma', 'mírame', 'baño', 'debieron', 'reproducirla', 'reducida', 'oso', 'sigue', 'medicamento', 'comienza', 'daño', 'correctas', 'seguramente', 'ninguna', 'importaría', 'online', 'cueva', 'asistido', 'ideas', 'otorga', 'películas', 'algún', 'cocinar', 'asesinato', 'decir', 'empleados', 'áfrica', 'saber', 'shanghái', 'quicio', 'limpia', 'fealdad', 'viagr ...

# %% [markdown]
# To start, use the `eng_model.wv.similarity(w1, w2)` to compare the similarities between these word pairs:
# + love & happy
# + water & ice
# + teacher & engineer

# %%
### START CODE
print(eng_model.wv.similarity('love', 'happy'))
print(eng_model.wv.similarity('water', 'ice'))
print(eng_model.wv.similarity('teacher', 'engineer'))

### END CODE
# Out:
# 0.14387816
# 0.032386575
# -0.125456

# %% [markdown]
# Next, using the `.most_similar(positive=w1, topn=z)`, here `w1` is the word you find to find similar words to and `topn` is the number of most similar words you'd like to return.
#
# Find the 3 most similar words in the Spanish corpus to:
# + juzgar (judge)
# + telefónico (telephone)
# + sol (sun)
#
# (Feel free to use Google Translate to translate the results!)

# %%
### START CODE
print(esp_model.wv.most_similar(positive='juzgar', topn=3))
print(esp_model.wv.most_similar(positive='telefónico', topn=3))
print(esp_model.wv.most_similar(positive='sol', topn=3))
### END CODE
# Out:
# [('pasma', 0.34155476093292236), ('debe', 0.33582815527915955), ('prestar', 0.31578561663627625)]
# [('corazón', 0.40503841638565063), ('cortado', 0.35685691237449646), ('defenderla', 0.340695321559906)]
# [('aliento', 0.30775752663612366), ('insulto', 0.29986828565597534), ('revisar', 0.2965880334377289)]

# %% [markdown]
# ### Visualising Embeddings
#
# Quantifying the similarity between word embeddings is great, but sometimes it is good to see what's happening graphically.
#
# Unfortunately our word embeddings have 100 dimensions and so visualising the raw data will be practically impossible, instead we will use a decomposition technique called PCA to reduce the 100 dimensions down to 2.
#
# You do not need to know how PCA words for this course, but if you'd like to find out more you can check out this fantastic [StatQuest Video](https://www.youtube.com/watch?v=FgakZw6K1QQ).
#
# Let's get started, first we need to extract the embeddings for each word we wish to plot. In the space below ccreate a list of word embeddings for the following words:
# + love
# + happy
# + water
# + ice
# + angry

# %%
words = ['love', 'happy', 'water', 'ice', 'angry']

# %%
### BEGIN CODE
vectors = [eng_model.wv['love'], eng_model.wv['happy'], eng_model.wv['water'], eng_model.wv['ice'], eng_model.wv['angry']]
### END CODE

# %% [markdown]
# Next, we need to create the PCA model which we will use to decompose our embeddings (the code is provided for you).

# %%
import sys
# !{sys.executable} -m pip install scikit-learn
# !{sys.executable} -m pip install matplotlib
# Out:
# Requirement already satisfied: scikit-learn in /opt/anaconda3/envs/hackathon/lib/python3.13/site-packages (1.9.0)
# Requirement already satisfied: numpy>=1.24.1 in /opt/anaconda3/envs/hackathon/lib/python3.13/site-packages (from scikit-learn) (2.5.1)
# Requirement already satisfied: scipy>=1.10.0 in /opt/anaconda3/envs/hackathon/lib/python3.13/site-packages (from scikit-learn) (1.18.0)
# Requirement already satisfied: joblib>=1.4.0 in /opt/anaconda3/envs/hackathon/lib/python3.13/site-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: narwhals>=2.0.1 in /opt/anaconda3/envs/hackathon/lib/python3.13/site-packages (from scikit-learn) (2.23.0)
# Requirement already satisfied: threadpoolctl>=3.5.0 in /opt/anaconda3/envs/hackathon/lib/python3.13/site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: matplotlib in /opt/anaconda3/envs/hackathon/lib/python3.13/site-packages (3.11.0)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/anaconda3/envs/hackathon/lib/python3.13/site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /opt/anaconda3/envs/hackathon/lib/python3.13/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/anaconda3/envs/hackathon/lib/python3.13/site-packages (from matplotlib) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/anaconda3/envs/hackathon/lib/python3.13/site-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: numpy>=1.25 in /opt/anaconda3/envs/hackathon/lib/python3.13/site-packages (from matplotlib) (2.5.1)
# Requirement already satisfied: packaging>=20.0 in /opt/anaconda3/envs/hackathon/lib/python3.13/site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=9 in /opt/anaconda3/envs/hackathon/lib/python3.13/site-packages (from matplotlib) (12.1.1)
# Requirement already satisfied: pyparsing>=3 in /opt/anaconda3/envs/hackathon/lib/python3.13/site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/anaconda3/envs/hackathon/lib/python3.13/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/envs/hackathon/lib/python3.13/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)

# %%
from sklearn.decomposition import PCA
decomposed_words = PCA(n_components=2).fit_transform(vectors) # n_components is the number of resulting dimensions

# %% [markdown]
# Finally, we can plot our decomposed word embeddings on a figure.

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(5, 5))
for i, word in enumerate(words):
    x, y = decomposed_words[i]
    plt.scatter(x, y)
    plt.text(x+0.001, y+0.001, word, fontsize=9)
plt.title("Word2Vec embeddings visualized in 2D")
plt.show()

# %% [markdown]
# Hopefully, what you see above is that happy & love are the closes words, angry is on the same 'side' as them but water and ice are seperate.
#
# ### Extra: Experiment Time
#
# Now you've embedded, visualised and compared words using static embeddings take some time to explore the parameters of the Word2Vec class and consider the following questions:
# > **Question:** What happens when you change to a skip-gram method?
#
# > **Question:** How does the window size impact the results?
#
# > **Question:** The number of hidden nodes indicates the size of the embedding, what happens when you change this up or down?

# %% [markdown]
# ## Part 3: Contextual Embeddings
#
# Moving onto contextual embeddings, this time we will use pre-trained BERT weights to create embeddings for the English corpus.
#
# > Note: As we are comparing embeddings in this lab we do not have a downstream task in which to train the task-specific parameters, if this is something you'd like to try, at the end of this lab there is an extension task you may complete.
#
# To do this, we will be using `transformers` a module which gives us BERT without the need for us to build it from scratch, I have provided the code below to load an BERT model and embed the English corpus.
#
# Be warned, this might take a while! Whilst it's computing, consider the following:
#
# > **Question:** Why would we use pretrained weights?

# %%
from transformers import BertTokenizer, BertModel
import torch

# %%
tokeniser = BertTokenizer.from_pretrained("bert-base-uncased")
model = BertModel.from_pretrained("bert-base-uncased")
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Loading weights:   0%|          | 0/199 [00:00<?, ?it/s]
# [transformers] BertModel LOAD REPORT from: bert-base-uncased
# Key                                        | Status     |  |
# -------------------------------------------+------------+--+-
# cls.predictions.transform.dense.bias       | UNEXPECTED |  |
# cls.predictions.transform.dense.weight     | UNEXPECTED |  |
# cls.predictions.bias                       | UNEXPECTED |  |
# cls.predictions.transform.LayerNorm.bias   | UNEXPECTED |  |
# cls.seq_relationship.bias                  | UNEXPECTED |  |
# cls.predictions.transform.LayerNorm.weight | UNEXPECTED |  |
# cls.seq_relationship.weight                | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.

# %%
import sys

# !{sys.executable} -m pip install --upgrade ipywidgets jupyter tqdm
# Out:
# Requirement already satisfied: ipywidgets in /opt/anaconda3/envs/hackathon/lib/python3.13/site-packages (8.1.8)
# Requirement already satisfied: jupyter in /opt/anaconda3/envs/hackathon/lib/python3.13/site-packages (1.1.1)
# Requirement already satisfied: tqdm in /opt/anaconda3/envs/hackathon/lib/python3.13/site-packages (4.68.4)
# Requirement already satisfied: comm>=0.1.3 in /opt/anaconda3/envs/hackathon/lib/python3.13/site-packages (from ipywidgets) (0.2.3)
# Requirement already satisfied: ipython>=6.1.0 in /opt/anaconda3/envs/hackathon/lib/python3.13/site-packages (from ipywidgets) (9.11.0)
# Requirement already satisfied: traitlets>=4.3.1 in /opt/anaconda3/envs/hackathon/lib/python3.13/site-packages (from ipywidgets) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in /opt/anaconda3/envs/hackathon/lib/python3.13/site-packages (from ipywidgets) (4.0.15)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in /opt/anaconda3/envs/hackathon/lib/python3.13/site-packages (from ipywidgets) (3.0.16)
# Requirement already satisfied: notebook in /opt/anaconda3/envs/hackathon/lib/python3.13/site-packages (from jupyter) (7.5.3)
# Requirement already satisfied: jupyter-console in /opt/anaconda3/envs/hackathon/lib/python3.13/site-packages (from jupyter) (6.6.3)
# Requirement already satisfied: nbconvert in /opt/anaconda3/envs/hackathon/lib/python3.13/site-packages (from jupyter) (7.17.0)
# Requirement already satisfied: ipykernel in /opt/anaconda3/envs/hackathon/lib/python3.13/site-packages (from jupyter) (7.2.0)
# Requirement already satisfied: jupyterlab in /opt/anaconda3/envs/hackathon/lib/python3.13/site-packages (from jupyter) (4.5.3)
# Requirement already satisfied: decorator>=5.1.0 in /opt/anaconda3/envs/hackathon/lib/python3.13/site-packages (from ipython>=6.1.0->ipywidgets) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in /opt/anaconda3/envs/hackathon/lib/python3.13/site-packages (from ipython>=6.1.0->ipywidgets) (1.1.1)
# Requirement already satisfied: jedi>=0.18.2 in /opt/anaconda3/envs/hackathon/lib/python3.13/site-packages (from ipython>=6.1.0->ipywidgets) (0.19.2)
# Requirement already satisfied: matplotlib-inline>=0.1.6 in /opt/anaconda3/envs/hackathon/lib/python3.13/site-packages (from ipython>=6.1.0->ipywidgets) (0.2.1)
# Requirement already satisfied: pexpect>4.6 in /opt/anaconda3/envs/hackathon/lib/python3.13/site-packages (from ipython>=6.1.0->ipywidgets) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /opt/anaconda3/envs/hackathon/lib/python3.13/site-packages (from ipython>=6.1.0->ipywidgets) (3.0.52)
# Requirement already satisfied: pygments>=2.14.0 in /opt/anaconda3/envs/hackathon/lib/python3.13/site-packages (from ipython>=6.1.0->ipywidgets) (2.19.2)
# Requirement already satisfied: stack_data>=0.6.0 in /opt/anaconda3/envs/hackathon/lib/python3.13/site-packages (from ipython>=6.1.0->ipywidgets) (0.6.3)
# Requirement already satisfied: wcwidth in /opt/anaconda3/envs/hackathon/lib/python3.13/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets) (0.2.14)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /opt/anaconda3/envs/hackathon/lib/python3.13/site-packages (from jedi>=0.18.2->ipython>=6.1.0->ipywidgets) (0.8.5)
# Requirement already satisfied: ptyprocess>=0.5 in /opt/anaconda3/envs/hackathon/lib/python3.13/site-packages (from pexpect>4.6->ipython>=6.1.0->ipywidgets) (0.7.0)
# Requirement already satisfied: executing>=1.2.0 in /opt/anaconda3/envs/hackathon/lib/python3.13/site-packages (from stack_data>=0.6.0->ipython>=6.1.0->ipywidgets) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in /opt/anaconda3/envs/hackathon/lib/python3.13/site-packages (from stack_data>=0.6.0->ipython>=6.1.0->ipywidgets) (3.0.1)
# Requirement already satisfied: pure_eval in /opt/anaconda3/envs/hackathon/lib/python3.13/site-packages (from stack_data>=0.6.0->ipython>=6.1.0->ipywidgets) (0.2.3)
# Requirement already satisfied: appnope>=0.1.2 in /opt/anaconda3/envs/hackathon/lib/python3.13/site-packages (from ipykernel->jupyter) (0.1.4)
# Requirement already satisfied: debugpy>=1.6.5 in /opt/anaconda3/envs/hackathon/lib/python3.13/site-packages (from ipykernel->jupyter) (1.8.16)
# Requirement already satisfied: jupyter-client>=8.8.0 in /opt/anaconda3/envs/hackathon/lib/python3.13/site-packages (from ipykernel->jupyter) (8.8.0)
# Requirement already satisfied: jupyter-core!=6.0.*,>=5.1 in /opt/anaconda3/envs/hackathon/lib/python3.13/site-packages (from ipykernel->jupyter) (5.9.1)
# Requirement already satisfied: nest-asyncio>=1.4 in /opt/anaconda3/envs/hackathon/lib/python3.13/site-packages (from ipykernel->jupyter) (1.6.0)
# Requirement already satisfied: packaging>=22 in /opt/anaconda3/envs/hackathon/lib/python3.13/site-packages (from ipykernel->jupyter) (25.0)
# Requirement already satisfied: psutil>=5.7 in /opt/anaconda3/envs/hackathon/lib/python3.13/site-packages (from ipykernel->jupyter) (7.0.0)
# Requirement already satisfied: pyzmq>=25 in /opt/anaconda3/envs/hackathon/lib/python3.13/site-packages (from ipykernel->jupyter) (27.1.0)
# Requirement already satisfied: tornado>=6.4.1 in /opt/anaconda3/envs/hackathon/lib/python3.13/site-packages (from ipykernel->jupyter) (6.5.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/envs/hackathon/lib/python3.13/site-packages (from jupyter-client>=8.8.0->ipykernel->jupyter) (2.9.0.post0)
# Requirement already satisfied: platformdirs>=2.5 in /opt/anaconda3/envs/hackathon/lib/python3.13/site-packages (from jupyter-core!=6.0.*,>=5.1->ipykernel->jupyter) (4.9.4)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/envs/hackathon/lib/python3.13/site-packages (from python-dateutil>=2.8.2->jupyter-client>=8.8.0->ipykernel->jupyter) (1.17.0)
# Requirement already satisfied: async-lru>=1.0.0 in /opt/anaconda3/envs/hackathon/lib/python3.13/site-packages (from jupyterlab->jupyter) (2.0.5)
# Requirement already satisfied: httpx<1,>=0.25.0 in /opt/anaconda3/envs/hackathon/lib/python3.13/site-packages (from jupyterlab->jupyter) (0.28.1)
# Requirement already satisfied: jinja2>=3.0.3 in /opt/anaconda3/envs/hackathon/lib/python3.13/site-packages (from jupyterlab->jupyter) (3.1.6)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in /opt/anaconda3/envs/hackathon/lib/python3.13/site-packages (from jupyterlab->jupyter) (2.3.0)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in /opt/anaconda3/envs/hackathon/lib/python3.13/site-packages (from jupyterlab->jupyter) (2.17.0)
# Requirement already satisfied: jupyterlab-server<3,>=2.28.0 in /opt/anaconda3/envs/hackathon/lib/python3.13/site-packages (from jupyterlab->jupyter) (2.28.0)
# Requirement already satisfied: notebook-shim>=0.2 in /opt/anaconda3/envs/hackathon/lib/python3.13/site-packages (from jupyterlab->jupyter) (0.2.4)
# Requirement already satisfied: setuptools>=41.1.0 in /opt/anaconda3/envs/hackathon/lib/python3.13/site-packages (from jupyterlab->jupyter) (80.10.2)
# Requirement already satisfied: anyio in /opt/anaconda3/envs/hackathon/lib/python3.13/site-packages (from httpx<1,>=0.25.0->jupyterlab->jupyter) (4.12.1)
# Requirement already satisfied: certifi in /opt/anaconda3/envs/hackathon/lib/python3.13/site-packages (from httpx<1,>=0.25.0->jupyterlab->jupyter) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in /opt/anaconda3/envs/hackathon/lib/python3.13/site-packages (from httpx<1,>=0.25.0->jupyterlab->jupyter) (1.0.9)
# Requirement already satisfied: idna in /opt/anaconda3/envs/hackathon/lib/python3.13/site-packages (from httpx<1,>=0.25.0->jupyterlab->jupyter) (3.11)
# Requirement already satisfied: h11>=0.16 in /opt/anaconda3/envs/hackathon/lib/python3.13/site-packages (from httpcore==1.*->httpx<1,>=0.25.0->jupyterlab->jupyter) (0.16.0)
# Requirement already satisfied: argon2-cffi>=21.1 in /opt/anaconda3/envs/hackathon/lib/python3.13/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (25.1.0)
# Requirement already satisfied: jupyter-events>=0.11.0 in /opt/anaconda3/envs/hackathon/lib/python3.13/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.12.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in /opt/anaconda3/envs/hackathon/lib/python3.13/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.5.4)
# Requirement already satisfied: nbformat>=5.3.0 in /opt/anaconda3/envs/hackathon/lib/python3.13/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (5.10.4)
# Requirement already satisfied: prometheus-client>=0.9 in /opt/anaconda3/envs/hackathon/lib/python3.13/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.24.1)
# Requirement already satisfied: send2trash>=1.8.2 in /opt/anaconda3/envs/hackathon/lib/python3.13/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in /opt/anaconda3/envs/hackathon/lib/python3.13/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in /opt/anaconda3/envs/hackathon/lib/python3.13/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.8.0)
# Requirement already satisfied: babel>=2.10 in /opt/anaconda3/envs/hackathon/lib/python3.13/site-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter) (2.17.0)
# Requirement already satisfied: json5>=0.9.0 in /opt/anaconda3/envs/hackathon/lib/python3.13/site-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter) (0.12.1)
# Requirement already satisfied: jsonschema>=4.18.0 in /opt/anaconda3/envs/hackathon/lib/python3.13/site-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter) (4.25.1)
# Requirement already satisfied: requests>=2.31 in /opt/anaconda3/envs/hackathon/lib/python3.13/site-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter) (2.32.5)
# Requirement already satisfied: argon2-cffi-bindings in /opt/anaconda3/envs/hackathon/lib/python3.13/site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (25.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/anaconda3/envs/hackathon/lib/python3.13/site-packages (from jinja2>=3.0.3->jupyterlab->jupyter) (3.0.2)
# Requirement already satisfied: attrs>=22.2.0 in /opt/anaconda3/envs/hackathon/lib/python3.13/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /opt/anaconda3/envs/hackathon/lib/python3.13/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /opt/anaconda3/envs/hackathon/lib/python3.13/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /opt/anaconda3/envs/hackathon/lib/python3.13/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter) (0.28.0)
# Requirement already satisfied: python-json-logger>=2.0.4 in /opt/anaconda3/envs/hackathon/lib/python3.13/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (4.0.0)
# Requirement already satisfied: pyyaml>=5.3 in /opt/anaconda3/envs/hackathon/lib/python3.13/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (6.0.3)
# Requirement already satisfied: rfc3339-validator in /opt/anaconda3/envs/hackathon/lib/python3.13/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /opt/anaconda3/envs/hackathon/lib/python3.13/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.1.1)
# Requirement already satisfied: fqdn in /opt/anaconda3/envs/hackathon/lib/python3.13/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.5.1)
# Requirement already satisfied: isoduration in /opt/anaconda3/envs/hackathon/lib/python3.13/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /opt/anaconda3/envs/hackathon/lib/python3.13/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (3.1.1)
# Requirement already satisfied: rfc3987-syntax>=1.1.0 in /opt/anaconda3/envs/hackathon/lib/python3.13/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.1.0)
# Requirement already satisfied: uri-template in /opt/anaconda3/envs/hackathon/lib/python3.13/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in /opt/anaconda3/envs/hackathon/lib/python3.13/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (25.10.0)
# Requirement already satisfied: beautifulsoup4 in /opt/anaconda3/envs/hackathon/lib/python3.13/site-packages (from nbconvert->jupyter) (4.14.3)
# Requirement already satisfied: bleach!=5.0.0 in /opt/anaconda3/envs/hackathon/lib/python3.13/site-packages (from bleach[css]!=5.0.0->nbconvert->jupyter) (6.3.0)
# Requirement already satisfied: defusedxml in /opt/anaconda3/envs/hackathon/lib/python3.13/site-packages (from nbconvert->jupyter) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /opt/anaconda3/envs/hackathon/lib/python3.13/site-packages (from nbconvert->jupyter) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in /opt/anaconda3/envs/hackathon/lib/python3.13/site-packages (from nbconvert->jupyter) (3.1.2)
# Requirement already satisfied: nbclient>=0.5.0 in /opt/anaconda3/envs/hackathon/lib/python3.13/site-packages (from nbconvert->jupyter) (0.10.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in /opt/anaconda3/envs/hackathon/lib/python3.13/site-packages (from nbconvert->jupyter) (1.5.1)
# Requirement already satisfied: webencodings in /opt/anaconda3/envs/hackathon/lib/python3.13/site-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert->jupyter) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in /opt/anaconda3/envs/hackathon/lib/python3.13/site-packages (from bleach[css]!=5.0.0->nbconvert->jupyter) (1.4.0)
# Requirement already satisfied: fastjsonschema>=2.15 in /opt/anaconda3/envs/hackathon/lib/python3.13/site-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (2.21.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/anaconda3/envs/hackathon/lib/python3.13/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/envs/hackathon/lib/python3.13/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter) (2.6.3)
# Requirement already satisfied: lark>=1.2.2 in /opt/anaconda3/envs/hackathon/lib/python3.13/site-packages (from rfc3987-syntax>=1.1.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.3.1)
# Requirement already satisfied: cffi>=1.0.1 in /opt/anaconda3/envs/hackathon/lib/python3.13/site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (2.0.0)
# Requirement already satisfied: pycparser in /opt/anaconda3/envs/hackathon/lib/python3.13/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (2.23)
# Requirement already satisfied: soupsieve>=1.6.1 in /opt/anaconda3/envs/hackathon/lib/python3.13/site-packages (from beautifulsoup4->nbconvert->jupyter) (2.5)
# Requirement already satisfied: typing-extensions>=4.0.0 in /opt/anaconda3/envs/hackathon/lib/python3.13/site-packages (from beautifulsoup4->nbconvert->jupyter) (4.15.0)
# Requirement already satisfied: arrow>=0.15.0 in /opt/anaconda3/envs/hackathon/lib/python3.13/site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.4.0)
# Requirement already satisfied: tzdata in /opt/anaconda3/envs/hackathon/lib/python3.13/site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (2026.3)

# %%
def generate_bert_embeddings(t, m, corpus):
  """ This method generates BERT embeddings using the given Word2Vec model and corpus """
  word_embeddings = []
  sentence_embeddings = []
  for sentence in tqdm(corpus):
    tokenised = t(' '.join(sentence), return_tensors="pt")
    embedding = m(**tokenised)
    word_embeddings.append(embedding.last_hidden_state.detach().numpy())
    sentence_embeddings.append(embedding.pooler_output.flatten())
  return word_embeddings, sentence_embeddings

# Generate embeddings
eng_embeddings, eng_sent_embeddings = generate_bert_embeddings(tokeniser, model, token_english[:10])
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]

# %% [markdown]
# ### Word Similarity
# Now you have an ELMo model and a method for generating embeddings we can now compare the contextualised embeddings with the static embeddings we generated earlier.
#
# To do this, retrieve the static English embeddings and contextualised English embeddings for the following words (the same words as earlier):
# + love
# + happy
# + water
# + ice
# + angry

# %%
words = ['love', 'happy', 'water', 'ice', 'angry']
static_embeddings = [eng_model.wv[word] for word in words]
contextual_embeddings, _ = generate_bert_embeddings(tokeniser, model, words)
# Out:
#   0%|          | 0/5 [00:00<?, ?it/s]

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %% [markdown]
# Using the cosine_similarity method, calculate the similarity between the following word pairs for both static and contextual embeddings:
#
# + love & happy
# + love & anger
# + water & ice
#
# You might get a warning to reshape your embeddings, simply add a `.reshape(1, -1)` following the embedding vector for example:
# `static_embeddings[0].reshape(1, -1)`.
#
# An example has been provided.

# %%
print(cosine_similarity(static_embeddings[0].reshape(1, -1), static_embeddings[1].reshape(1, -1)))
print(cosine_similarity(contextual_embeddings[0][0][0, :].reshape(1, -1), contextual_embeddings[0][0][1, :].reshape(1, -1)))

### BEGIN CODE

print(cosine_similarity(static_embeddings[0].reshape(1, -1), static_embeddings[4].reshape(1, -1)))
print(cosine_similarity(contextual_embeddings[0][0][0, :].reshape(1, -1), contextual_embeddings[0][0][4, :].reshape(1, -1)))

print(cosine_similarity(static_embeddings[2].reshape(1, -1), static_embeddings[3].reshape(1, -1)))
print(cosine_similarity(contextual_embeddings[0][0][2, :].reshape(1, -1), contextual_embeddings[0][0][3, :].reshape(1, -1)))

### END CODE
# Out:
# [[0.14387816]]
# [[0.5547693]]
# [[-0.0007899]]
# [[0.19128287]]
# [[0.03238657]]
# [[0.84788644]]

# %% [markdown]
# > **Question:** What differences and similarities do you notice?
#
# > **Question:** Why do you think these differences appear?

# %% [markdown]
# ### Extra: Visualise Contextual Embeddings
#
# Using the contextual embedding model you created above you an now try plotting different words using the same PCA approach we introduced earlier.
#
# The benefit of the pre-trained weights approach is that you will be able to access far more words.
#
# > **Question:** Plot king, queen, woman, man, what do you notice?

# %% [markdown]
# ## Optional Exercise (Challenging)
#
# If you're feeling confident you can try applying ELMo embeddings to the sentiment analysis task from last week. You will need the support of the allennlp documentation. If you want to instead try a simpler problem, try using Word2Vec first then try ELMo. Remember for ELMo you should also train the task-specific parameters!

# %% [markdown]
# ## Wrap-up
# Well done on finishing up this week's lab! I hope you were able to practice what we learnt in the lectures and now have a better understanding of how word embeddings are used to relate words together.
#
# Next week we will be looking at how we can use classical approaches to further enhance our understanding of the words in corpora.
